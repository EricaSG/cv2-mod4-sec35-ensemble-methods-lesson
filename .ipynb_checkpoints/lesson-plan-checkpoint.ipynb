# %% [markdown]
# ### Ensemble Methods Section 35

# %% [markdown]
# ### Questions

# %% [markdown]
# ### Objectives
# YWBAT
# - Compare and contrast decision trees with Random Forest Models
# - Compare and contrast ADABoost with Gradient Boosting
# - Condition our data for a single model
# - Tune hyperparameters to increase desired metric
# - Analyze model for use case
# - Build a pipeline that will analyze an individual patient
#
# ### Outline
# - Random Forests
# - Adaboost and Gradient Boosted Random Forests
# - Load in a dataset and try to solve the problem using Forest classifiers

# %% [markdown]
# ### What is a random forest?
# A random forest is a collection of decision trees where each decision tree is built by:
# - random set of parameters
# - similar tree hyperparameters
#     - maybe you can randomize each trees hyperparameters
#
#
# How is a point assigned a label in a random forest?
# - Each decision tree assigns a point a label
# - The labels are then counted and the max count wins
#
#
# ### Pros and Cons
# Pros
# - Interpretability
#     - you can interpret individual trees
#     - strong performance
#     - random sampling of features to reduce impact of strong features
#         - prevents overfitting
#     - useful for datasets with high dimensionality of features
#         - each tree is now reduced to a smaller dimension
#         - you might miss important feature signals
#     - good for small sample sizes because of bootstrap aggregation
#         - more resilient to high variance
#
# Cons
# - Computationally expensive
# - Greedy forests can occur if you sample too many features from your feature set on each tree
# - Tree depth can cause greediness
#
#
# ### Real Life Structures
#
#
# ### Analyze

# %% [markdown]
# ### Adaboosting - sampling
# * Adaptive Boosting
#     * Weak Learners are adapting to previously misclassified data
# * We're building a complex tree using stumps which are trees with 1 feature and 1 split
#
# ![](images/adaboost.jpg)
#
#
#
# ### Gradient boosting - residuals
# * Building trees that fit on the residuals
#
# ![](images/gradboost.png)

# %% [markdown]
# ### to use XGBOOST use
# ```import os
# os.environ['KMP_DUPLICATE_LIB_OK']='True'```

# %% [markdown]
# ### Outline

# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler

from mlxtend.feature_selection import SequentialFeatureSelector as sfs

import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(42)

# %% [markdown]
# ### Let's build some models

# %%
df = pd.read_csv("./churn.csv")
df.head()
# Out:
#    state  account_length  area_code  phone_number  international_plan  \
# 0     16             128        415          2845                   0
# 1     35             107        415          2301                   0
# 2     31             137        415          1616                   0
# 3     35              84        408          2510                   1
# 4     36              75        415           155                   1
#
#    voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                1                     25              265.1              110
# 1                1                     26              161.6              123
# 2                0                      0              243.4              114
# 3                0                      0              299.4               71
# 4                0                      0              166.7              113
#
#    total_day_charge  ...  total_eve_calls  total_eve_charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
# 2             41.38  ...              110             10.30
# 3             50.90  ...               88              5.26
# 4             28.34  ...              122             12.61
#
#    total_night_minutes  total_night_calls  total_night_charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    total_intl_minutes  total_intl_calls  total_intl_charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    number_customer_service_calls  class
# 0                              1      0
# 1                              1      0
# 2                              0      0
# 3                              2      0
# 4                              3      0
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
# state                            5000 non-null int64
# account_length                   5000 non-null int64
# area_code                        5000 non-null int64
# phone_number                     5000 non-null int64
# international_plan               5000 non-null int64
# voice_mail_plan                  5000 non-null int64
# number_vmail_messages            5000 non-null int64
# total_day_minutes                5000 non-null float64
# total_day_calls                  5000 non-null int64
# total_day_charge                 5000 non-null float64
# total_eve_minutes                5000 non-null float64
# total_eve_calls                  5000 non-null int64
# total_eve_charge                 5000 non-null float64
# total_night_minutes              5000 non-null float64
# total_night_calls                5000 non-null int64
# total_night_charge               5000 non-null float64
# total_intl_minutes               5000 non-null float64
# total_intl_calls                 5000 non-null int64
# total_intl_charge                5000 non-null float64
# number_customer_service_calls    5000 non-null int64
# class                            5000 non-null int64
# dtypes: float64(8), int64(13)
# memory usage: 820.4 KB

# %%
df.isna().sum()
# Out:
# state                            0
# account_length                   0
# area_code                        0
# phone_number                     0
# international_plan               0
# voice_mail_plan                  0
# number_vmail_messages            0
# total_day_minutes                0
# total_day_calls                  0
# total_day_charge                 0
# total_eve_minutes                0
# total_eve_calls                  0
# total_eve_charge                 0
# total_night_minutes              0
# total_night_calls                0
# total_night_charge               0
# total_intl_minutes               0
# total_intl_calls                 0
# total_intl_charge                0
# number_customer_service_calls    0
# class                            0
# dtype: int64

# %% [markdown]
# ### Count your labels

# %%
df["class"].value_counts()
# Out:
# 0    4293
# 1     707
# Name: class, dtype: int64

# %% [markdown]
# ### we have unbalanced data, which is bad

# %%
df2 = df.drop(columns=["phone_number", "number_vmail_messages", "state", "area_code"])
df2.head()
# Out:
#    account_length  international_plan  voice_mail_plan  total_day_minutes  \
# 0             128                   0                1              265.1
# 1             107                   0                1              161.6
# 2             137                   0                0              243.4
# 3              84                   1                0              299.4
# 4              75                   1                0              166.7
#
#    total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# 0              110             45.07              197.4               99
# 1              123             27.47              195.5              103
# 2              114             41.38              121.2              110
# 3               71             50.90               61.9               88
# 4              113             28.34              148.3              122
#
#    total_eve_charge  total_night_minutes  total_night_calls  \
# 0             16.78                244.7                 91
# 1             16.62                254.4                103
# 2             10.30                162.6                104
# 3              5.26                196.9                 89
# 4             12.61                186.9                121
#
#    total_night_charge  total_intl_minutes  total_intl_calls  \
# 0               11.01                10.0                 3
# 1               11.45                13.7                 3
# 2                7.32                12.2                 5
# 3                8.86                 6.6                 7
# 4                8.41                10.1                 3
#
#    total_intl_charge  number_customer_service_calls  class
# 0               2.70                              1      0
# 1               3.70                              1      0
# 2               3.29                              0      0
# 3               1.78                              2      0
# 4               2.73                              3      0

# %%
df2.corr()
# Out:
#                                account_length  international_plan  \
# account_length                       1.000000            0.014681
# international_plan                   0.014681            1.000000
# voice_mail_plan                     -0.006650            0.009054
# total_day_minutes                   -0.001017            0.028138
# total_day_calls                      0.028240            0.008102
# total_day_charge                    -0.001019            0.028141
# total_eve_minutes                   -0.009591            0.021235
# total_eve_calls                      0.009143            0.002505
# total_eve_charge                    -0.009587            0.021234
# total_night_minutes                  0.000668           -0.026508
# total_night_calls                   -0.007825            0.005623
# total_night_charge                   0.000656           -0.026510
# total_intl_minutes                   0.001291            0.031799
# total_intl_calls                     0.014277            0.004493
# total_intl_charge                    0.001292            0.031751
# number_customer_service_calls       -0.001445           -0.012974
# class                                0.021203            0.259123
#
#                                voice_mail_plan  total_day_minutes  \
# account_length                       -0.006650          -0.001017
# international_plan                    0.009054           0.028138
# voice_mail_plan                       1.000000           0.002059
# total_day_minutes                     0.002059           1.000000
# total_day_calls                      -0.001735           0.001935
# total_day_charge                      0.002056           1.000000
# total_eve_minutes                     0.023328          -0.010750
# total_eve_calls                      -0.005916           0.008128
# total_eve_charge                      0.023332          -0.010760
# total_night_minutes                   0.005524           0.011799
# total_night_calls                     0.009176           0.004236
# total_night_charge                    0.005522           0.011783
# total_intl_minutes                    0.004116          -0.019486
# total_intl_calls                     -0.007525          -0.001303
# total_intl_charge                     0.004165          -0.019415
# number_customer_service_calls        -0.014453           0.002733
# class                                -0.110698           0.207705
#
#                                total_day_calls  total_day_charge  \
# account_length                        0.028240         -0.001019
# international_plan                    0.008102          0.028141
# voice_mail_plan                      -0.001735          0.002056
# total_day_minutes                     0.001935          1.000000
# total_day_calls                       1.000000          0.001936
# total_day_charge                      0.001936          1.000000
# total_eve_minutes                    -0.000699         -0.010747
# total_eve_calls                       0.003754          0.008129
# total_eve_charge                     -0.000695         -0.010757
# total_night_minutes                   0.002804          0.011801
# total_night_calls                    -0.008308          0.004235
# total_night_charge                    0.002802          0.011785
# total_intl_minutes                    0.013097         -0.019490
# total_intl_calls                      0.010893         -0.001307
# total_intl_charge                     0.013161         -0.019419
# number_customer_service_calls        -0.010739          0.002726
# class                                 0.016130          0.207700
#
#                                total_eve_minutes  total_eve_calls  \
# account_length                         -0.009591         0.009143
# international_plan                      0.021235         0.002505
# voice_mail_plan                         0.023328        -0.005916
# total_day_minutes                      -0.010750         0.008128
# total_day_calls                        -0.000699         0.003754
# total_day_charge                       -0.010747         0.008129
# total_eve_minutes                       1.000000         0.002763
# total_eve_calls                         0.002763         1.000000
# total_eve_charge                        1.000000         0.002778
# total_night_minutes                    -0.016639         0.001781
# total_night_calls                       0.013420        -0.013682
# total_night_charge                     -0.016642         0.001799
# total_intl_minutes                      0.000137        -0.007458
# total_intl_calls                        0.008388         0.005574
# total_intl_charge                       0.000159        -0.007507
# number_customer_service_calls          -0.013823         0.006235
# class                                   0.089288        -0.006284
#
#                                total_eve_charge  total_night_minutes  \
# account_length                        -0.009587             0.000668
# international_plan                     0.021234            -0.026508
# voice_mail_plan                        0.023332             0.005524
# total_day_minutes                     -0.010760             0.011799
# total_day_calls                       -0.000695             0.002804
# total_day_charge                      -0.010757             0.011801
# total_eve_minutes                      1.000000            -0.016639
# total_eve_calls                        0.002778             0.001781
# total_eve_charge                       1.000000            -0.016649
# total_night_minutes                   -0.016649             1.000000
# total_night_calls                      0.013422             0.026972
# total_night_charge                    -0.016652             0.999999
# total_intl_minutes                     0.000132            -0.006721
# total_intl_calls                       0.008393            -0.017214
# total_intl_charge                      0.000155            -0.006655
# number_customer_service_calls         -0.013836            -0.008533
# class                                  0.089282             0.045677
#
#                                total_night_calls  total_night_charge  \
# account_length                         -0.007825            0.000656
# international_plan                      0.005623           -0.026510
# voice_mail_plan                         0.009176            0.005522
# total_day_minutes                       0.004236            0.011783
# total_day_calls                        -0.008308            0.002802
# total_day_charge                        0.004235            0.011785
# total_eve_minutes                       0.013420           -0.016642
# total_eve_calls                        -0.013682            0.001799
# total_eve_charge                        0.013422           -0.016652
# total_night_minutes                     0.026972            0.999999
# total_night_calls                       1.000000            0.026949
# total_night_charge                      0.026949            1.000000
# total_intl_minutes                      0.000391           -0.006717
# total_intl_calls                       -0.000156           -0.017182
# total_intl_charge                       0.000368           -0.006650
# number_customer_service_calls          -0.008283           -0.008530
# class                                  -0.006986            0.045673
#
#                                total_intl_minutes  total_intl_calls  \
# account_length                           0.001291          0.014277
# international_plan                       0.031799          0.004493
# voice_mail_plan                          0.004116         -0.007525
# total_day_minutes                       -0.019486         -0.001303
# total_day_calls                          0.013097          0.010893
# total_day_charge                        -0.019490         -0.001307
# total_eve_minutes                        0.000137          0.008388
# total_eve_calls                         -0.007458          0.005574
# total_eve_charge                         0.000132          0.008393
# total_night_minutes                     -0.006721         -0.017214
# total_night_calls                        0.000391         -0.000156
# total_night_charge                      -0.006717         -0.017182
# total_intl_minutes                       1.000000          0.016791
# total_intl_calls                         0.016791          1.000000
# total_intl_charge                        0.999993          0.016900
# number_customer_service_calls           -0.012122         -0.019147
# class                                    0.063285         -0.046893
#
#                                total_intl_charge  \
# account_length                          0.001292
# international_plan                      0.031751
# voice_mail_plan                         0.004165
# total_day_minutes                      -0.019415
# total_day_calls                         0.013161
# total_day_charge                       -0.019419
# total_eve_minutes                       0.000159
# total_eve_calls                        -0.007507
# total_eve_charge                        0.000155
# total_night_minutes                    -0.006655
# total_night_calls                       0.000368
# total_night_charge                     -0.006650
# total_intl_minutes                      0.999993
# total_intl_calls                        0.016900
# total_intl_charge                       1.000000
# number_customer_service_calls          -0.012180
# class                                   0.063275
#
#                                number_customer_service_calls     class
# account_length                                     -0.001445  0.021203
# international_plan                                 -0.012974  0.259123
# voice_mail_plan                                    -0.014453 -0.110698
# total_day_minutes                                   0.002733  0.207705
# total_day_calls                                    -0.010739  0.016130
# total_day_charge                                    0.002726  0.207700
# total_eve_minutes                                  -0.013823  0.089288
# total_eve_calls                                     0.006235 -0.006284
# total_eve_charge                                   -0.013836  0.089282
# total_night_minutes                                -0.008533  0.045677
# total_night_calls                                  -0.008283 -0.006986
# total_night_charge                                 -0.008530  0.045673
# total_intl_minutes                                 -0.012122  0.063285
# total_intl_calls                                   -0.019147 -0.046893
# total_intl_charge                                  -0.012180  0.063275
# number_customer_service_calls                       1.000000  0.212564
# class                                               0.212564  1.000000

# %% [markdown]
# ### Let's build a out of box random forest

# %%
clf = RandomForestClassifier(criterion='entropy', max_depth=5)

# %%
X, y = df.drop("class", axis=1), df["class"]

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X, y, train_size=0.70)

# %%
clf.fit(xtrain, ytrain)
# Out:
# /Users/rafael/anaconda3/envs/flatiron-env/lib/python3.6/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#                        max_depth=5, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
clf.score(xtest, ytest)
# Out:
# 0.9033333333333333

# %%
ytest_preds = clf.predict(xtest)

# %%
confusion_matrix(ytest, ytest_preds)
# Out:
# array([[1284,    9],
#        [ 136,   71]])

# %% [markdown]
# ### How do we deal with imbalanced data?

# %%
from imblearn.over_sampling import RandomOverSampler
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-33-58c6a4a77bcd> in <module>
# ----> 1 from imblearn.over_sampling import RandomOverSampler
#
# ~/anaconda3/envs/flatiron-env/lib/python3.6/site-packages/imblearn/__init__.py in <module>
#      32     Module which allowing to create pipeline with scikit-learn estimators.
#      33 """
# ---> 34 from . import combine
#      35 from . import ensemble
#      36 from . import exceptions
#
# ~/anaconda3/envs/flatiron-env/lib/python3.6/site-packages/imblearn/combine/__init__.py in <module>
#       3 """
#       4
# ----> 5 from ._smote_enn import SMOTEENN
#       6 from ._smote_tomek import SMOTETomek
#       7
#
# ~/anaconda3/envs/flatiron-env/lib/python3.6/site-packages/imblearn/combine/_smote_enn.py in <module>
#       9
#      10 from ..base import BaseSampler
# ---> 11 from ..over_sampling import SMOTE
#      12 from ..over_sampling.base import BaseOverSampler
#      13 from ..under_sampling import EditedNearestNeighbours
#
# ~/anaconda3/envs/flatiron-env/lib/python3.6/site-packages/imblearn/over_sampling/__init__.py in <module>
#       6 from ._adasyn import ADASYN
#       7 from ._random_over_sampler import RandomOverSampler
# ----> 8 from ._smote import SMOTE
#       9 from ._smote import BorderlineSMOTE
#      10 from ._smote import KMeansSMOTE
#
# ~/anaconda3/envs/flatiron-env/lib/python3.6/site-packages/imblearn/over_sampling/_smote.py in <module>
#      16
#      17 from sklearn.base import clone
# ---> 18 from sklearn.cluster import MiniBatchKMeans
#      19 from sklearn.metrics import pairwise_distances
#      20 from sklearn.preprocessing import OneHotEncoder
#
# ~/anaconda3/envs/flatiron-env/lib/python3.6/site-packages/sklearn/cluster/__init__.py in <module>
#       4 """
#       5
# ----> 6 from ._spectral import spectral_clustering, SpectralClustering
#       7 from ._mean_shift import (mean_shift, MeanShift,
#       8                           estimate_bandwidth, get_bin_seeds)
#
# ~/anaconda3/envs/flatiron-env/lib/python3.6/site-packages/sklearn/cluster/_spectral.py in <module>
#      15 from ..metrics.pairwise import pairwise_kernels
#      16 from ..neighbors import kneighbors_graph, NearestNeighbors
# ---> 17 from ..manifold import spectral_embedding
#      18 from ._k_means import k_means
#      19
#
# ~/anaconda3/envs/flatiron-env/lib/python3.6/site-packages/sklearn/manifold/__init__.py in <module>
#       6 from ._isomap import Isomap
#       7 from ._mds import MDS, smacof
# ----> 8 from ._spectral_embedding import SpectralEmbedding, spectral_embedding
#       9 from ._t_sne import TSNE, trustworthiness
#      10
#
# ~/anaconda3/envs/flatiron-env/lib/python3.6/site-packages/sklearn/manifold/_spectral_embedding.py in <module>
#      18 from ..utils import check_random_state, check_array, check_symmetric
#      19 from ..utils.extmath import _deterministic_vector_sign_flip
# ---> 20 from ..utils.fixes import lobpcg
#      21 from ..metrics.pairwise import rbf_kernel
#      22 from ..neighbors import kneighbors_graph, NearestNeighbors
#
# ImportError: cannot import name 'lobpcg'
